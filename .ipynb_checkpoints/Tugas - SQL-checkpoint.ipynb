# %% [markdown]
# # LATIHAN
#
# Single entity
# 1. Prepare a list of offices sorted by country, state, city.
# 2. How many employees are there in the company?
# 3. What is the total of payments received?
# 4. List the product lines that contain 'Cars'.
# 5. Report total payments for October 28, 2004.
# 6. Report those payments greater than \$100,000.
# 7. List the products in each product line.
# 8. How many products in each product line?
# 9. What is the minimum payment received?
# 10. List all payments greater than twice the average payment.
# 11. What is the average percentage markup of the MSRP on buyPrice?
# 12. How many distinct products does ClassicModels sell?
# 13. Report the name and city of customers who don't have sales representatives?
# 14. What are the names of executives with VP or Manager in their title? Use the CONCAT function to combine the employee's first name and last name into a single field for reporting.
# 15. Which orders have a value greater than $5,000?

# %% [markdown]
# <img src="http://www.mysqltutorial.org/wp-content/uploads/2009/12/MySQL-Sample-Database-Schema.png" />

# %% [markdown]
# ### 1. Prepare a list of offices sorted by country, state, city.

# %%
import pymysql
import pandas as pd

host = '127.0.0.1'
port = "3306"
user = 'root'
password = ''
database = 'classicmodels'

conn = pymysql.connect(
    host=host,
    port=int(port),
    user=user,
    passwd=password,
    db=database,
    charset='utf8mb4')

def run(sql):
    df = pd.read_sql_query(sql,conn)
    return df

# %%
run("SELECT officeCode,country,state,city FROM offices  ORDER BY country,state,city desc")
# Out:
#   officeCode    country       state           city
# 0          6  Australia        None         Sydney
# 1          4     France        None          Paris
# 2          5      Japan  Chiyoda-Ku          Tokyo
# 3          7         UK        None         London
# 4          1        USA          CA  San Francisco
# 5          2        USA          MA         Boston
# 6          3        USA          NY            NYC

# %% [markdown]
# ### 2. How many employees are there in the company?

# %%
run("select count(employeeNumber) as 'Number Of Employee' from employees")
# Out:
#    Number Of Employee
# 0                  23

# %% [markdown]
# ### 3. What is the total of payments received?

# %%
run ("select sum(amount) as 'Total of Payment' from payments")
# Out:
#    Total of Payment
# 0        8853839.23

# %% [markdown]
# ### 4. List the product lines that contain 'Cars'.

# %%
run ("select productLine from productlines where productLine LIKE '%Cars%'")
# Out:
#     productLine
# 0  Classic Cars
# 1  Vintage Cars

# %% [markdown]
# ### 5. Report total payments for October 28, 2004.

# %%
run ("select SUM(amount) as 'Total payments for October 28, 2004' from payments WHERE paymentDate='2004-10-28'")
# Out:
#    Total payments for October 28, 2004
# 0                             47411.33

# %% [markdown]
# ### 6. Report those payments greater than $100,000.

# %%
run('select * from payments WHERE amount > 100000')
# Out:
#    customerNumber checkNumber paymentDate     amount
# 0             124    AE215433  2005-03-05  101244.59
# 1             124    KI131716  2003-08-15  111654.40
# 2             141     ID10962  2004-12-31  116208.40
# 3             141    JE105477  2005-03-18  120166.58
# 4             148    KM172879  2003-12-26  105743.00

# %% [markdown]
# ### 7. List the products in each product line.

# %%
run("select productLine,productName from products ORDER BY productLine, productName")
# Out:
#           productLine                                  productName
# 0        Classic Cars                  1948 Porsche 356-A Roadster
# 1        Classic Cars               1948 Porsche Type 356 Roadster
# 2        Classic Cars                           1949 Jaguar XK 120
# 3        Classic Cars                     1952 Alpine Renault 1300
# 4        Classic Cars                            1952 Citroen-15CV
# 5        Classic Cars                      1956 Porsche 356A Coupe
# 6        Classic Cars                    1957 Corvette Convertible
# 7        Classic Cars                        1957 Ford Thunderbird
# 8        Classic Cars          1958 Chevy Corvette Limited Edition
# 9        Classic Cars                        1961 Chevrolet Impala
# 10       Classic Cars                       1962 LanciaA Delta 16V
# 11       Classic Cars                        1965 Aston Martin DB5
# 12       Classic Cars                    1966 Shelby Cobra 427 S/C
# ...

# %% [markdown]
# ### 8. How many products in each product line?

# %%
run("select productLine,count(productName) as 'Number of Products' from products GROUP BY productLine")
# Out:
#         productLine  Number of Products
# 0      Classic Cars                  38
# 1       Motorcycles                  13
# 2            Planes                  12
# 3             Ships                   9
# 4            Trains                   3
# 5  Trucks and Buses                  11
# 6      Vintage Cars                  24

# %% [markdown]
# ### 9. What is the minimum payment received?

# %%
run ("select MIN(amount) as 'The Minimum Payment Received' from payments")
# Out:
#    The Minimum Payment Received
# 0                        615.45

# %% [markdown]
# ### 10. List all payments greater than twice the average payment.

# %%
run("select AVG(amount) as 'Average Payment' from payments")
# Out:
#    Average Payment
# 0     32431.645531

# %%
run("select * from payments WHERE amount>2*(select AVG(amount) from payments)")
# Out:
#     customerNumber checkNumber paymentDate     amount
# 0              114    MA765515  2004-12-15   82261.22
# 1              124    AE215433  2005-03-05  101244.59
# 2              124    BG255406  2004-08-28   85410.87
# 3              124     ET64396  2005-04-16   83598.04
# 4              124    KI131716  2003-08-15  111654.40
# 5              141     ID10962  2004-12-31  116208.40
# 6              141    IN446258  2005-03-25   65071.26
# 7              141    JE105477  2005-03-18  120166.58
# 8              148    KM172879  2003-12-26  105743.00
# 9              167    GN228846  2003-12-03   85024.46
# 10             239    NQ865547  2004-03-15   80375.24
# 11             321     DJ15149  2003-11-03   85559.12
# 12             323    AL493079  2005-05-23   75020.13

# %% [markdown]
# ### 11. What is the average percentage markup of the MSRP on buyPrice?

# %%
run("""select AVG((MSRP-buyPrice)/buyPrice*100) 
as 'the average percentage markup of the MSRP on buyPrice' from products""")
# Out:
#    the average percentage markup of the MSRP on buyPrice
# 0                                          88.702392

# %% [markdown]
# ### 12. How many distinct products does ClassicModels sell?

# %%
run("select count(DISTINCT productName) as 'Number of distinct products that ClassicModels sells' from products")
# Out:
#    Number of distinct products that ClassicModels sells
# 0                                                110

# %% [markdown]
# ### 13. Report the name and city of customers who don't have sales representatives?

# %%
run("select customerName,city,salesRepEmployeeNumber from customers WHERE salesRepEmployeeNumber IS NULL")
# Out:
#                       customerName              city salesRepEmployeeNumber
# 0               Havel & Zbyszek Co          Warszawa                   None
# 1                Porto Imports Co.            Lisboa                   None
# 2       Asian Shopping Network, Co         Singapore                   None
# 3                  Natürlich Autos         Cunewalde                   None
# 4                    ANG Resellers            Madrid                   None
# 5         Messner Shopping Network         Frankfurt                   None
# 6                Franken Gifts, Co           München                   None
# 7                BG&E Collectables          Fribourg                   None
# 8                 Schuyler Imports         Amsterdam                   None
# 9                 Der Hund Imports            Berlin                   None
# 10       Cramer Spezialitäten, Ltd       Brandenburg                   None
# ...

# %% [markdown]
# ### 14. What are the names of executives with VP or Manager in their title? Use the CONCAT function to combine the employee's first name and last name into a single field for reporting.

# %%
run("""select CONCAT(firstName,' ',lastName) as 'Name', jobTitle from employees 
WHERE jobTitle LIKE '%VP%' OR jobTitle LIKE '%Manager%'""")
# Out:
#                 Name              jobTitle
# 0     Mary Patterson              VP Sales
# 1      Jeff Firrelli          VP Marketing
# 2  William Patterson  Sales Manager (APAC)
# 3      Gerard Bondur   Sale Manager (EMEA)
# 4        Anthony Bow    Sales Manager (NA)

# %% [markdown]
# ### 15. Which orders have a value greater than $5,000?

# %%
run ("""select ordernumber,quantityOrdered*priceEach as 'OrderValues' from orderDetails 
     GROUP BY ordernumber HAVING OrderValues>5000""")
# Out:
#      ordernumber  OrderValues
# 0          10103      5571.80
# 1          10105      6392.00
# 2          10108      5457.54
# 3          10112      5717.64
# 4          10115      5123.94
# 5          10117      6445.89
# 6          10119      5192.48
# 7          10122      6537.72
# 8          10126      7817.74
# 9          10127      8889.50
# 10         10135      7273.14
# 11         10137      5092.12
# 12         10140      6898.28
# 13         10142      5485.92
# 14         10143      6530.72
# 15         10147      7751.52
# 16         10150      8197.20
# 17         10165      7406.08
# 18         10166      5873.37
# 19         10167      5445.44
# 20         10170      5464.69
# 21         10174      7067.58
# 22         10176      5485.92
# 23         10194      8550.78
# 24         10195      5806.50
# 25         10196      9571.08
# 26         10197      5324.40
# 27         10198      6292.02
# 28         10206      9568.73
# 29         10208      8124.98
# ...
